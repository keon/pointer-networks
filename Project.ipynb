# %%
from keras.models import Model
from keras.layers import LSTM, Input, Embedding
from keras.callbacks import LearningRateScheduler
from keras.utils.np_utils import to_categorical
from PointerLSTM import PointerLSTM
import pickle
import tsp_data as tsp
import numpy as np
import keras

# %%
def scheduler(epoch):
    if epoch < nb_epochs/4:
        return learning_rate
    elif epoch < nb_epochs/2:
        return learning_rate*0.5
    return learning_rate*0.1

# %%
print("preparing dataset...")
t = tsp.Tsp()
X, Y = t.next_batch(10)
x_test, y_test = t.next_batch(10)

YY = []
for y in Y:
    YY.append(to_categorical(y))
YY = np.asarray(YY)

hidden_size = 128
seq_len = 10
nb_epochs = 100
learning_rate = 0.1

print("building model...")
main_input = Input(shape=(seq_len, 2), name='main_input')
print(main_input.shape)

encoder,state_h, state_c = LSTM(hidden_size,return_sequences = True, name="encoder",return_state=True)(main_input)

decoder = PointerLSTM(hidden_size, name="decoder")(encoder,states=[state_h, state_c])

model = Model(main_input, decoder)
print(model.summary())
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X, YY, epochs=nb_epochs, batch_size=64,)
l = model.predict(x_test)
#print(l)
print('evaluate : ',model.evaluate(x_test,to_categorical(y_test)))
print("------")
#print(to_categorical(y_test))
model.save_weights('model_weight_100.hdf5')
# Out:
# preparing dataset...
# preparing dataset... 0/10
# preparing dataset... 1/10
# preparing dataset... 2/10
# preparing dataset... 3/10
# preparing dataset... 4/10
# preparing dataset... 5/10
# preparing dataset... 6/10
# preparing dataset... 7/10
# preparing dataset... 8/10
# preparing dataset... 9/10
# preparing dataset... 0/10
# preparing dataset... 1/10
# preparing dataset... 2/10
# preparing dataset... 3/10
# preparing dataset... 4/10
# preparing dataset... 5/10
# preparing dataset... 6/10
# preparing dataset... 7/10
# preparing dataset... 8/10
# preparing dataset... 9/10
# building model...
# (None, 10, 2)
# Tensor("pointer_lstm/attention/Reshape:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_1:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_2:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_3:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_4:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_5:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_6:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_7:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_8:0", shape=(None, 10), dtype=float32)
# Tensor("pointer_lstm/attention/Reshape_9:0", shape=(None, 10), dtype=float32)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  main_input (InputLayer)        [(None, 10, 2)]      0           []
#
#  encoder (LSTM)                 [(None, 10, 128),    67072       ['main_input[0][0]']
#                                  (None, 128),
#                                  (None, 128)]
#
#  pointer_lstm (PointerLSTM)     (None, 10, 10)       164480      ['encoder[0][0]',
#                                                                   'encoder[0][1]',
#                                                                   'encoder[0][2]']
#
# ==================================================================================================
# Total params: 231,552
# Trainable params: 231,552
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/100
# Tensor("model/pointer_lstm/attention/Reshape:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_1:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_2:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_3:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_4:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_5:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_6:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_7:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_8:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_9:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_1:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_2:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_3:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_4:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_5:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_6:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_7:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_8:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_9:0", shape=(None, 10), dtype=float32)
# 1/1 [==============================] - 13s 13s/step - loss: 2.3069 - accuracy: 0.1000
# Epoch 2/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.2977 - accuracy: 0.1000
# Epoch 3/100
# 1/1 [==============================] - 0s 19ms/step - loss: 2.2906 - accuracy: 0.1300
# Epoch 4/100
# 1/1 [==============================] - 0s 20ms/step - loss: 2.2808 - accuracy: 0.1500
# Epoch 5/100
# 1/1 [==============================] - 0s 24ms/step - loss: 2.2674 - accuracy: 0.2000
# Epoch 6/100
# 1/1 [==============================] - 0s 21ms/step - loss: 2.2503 - accuracy: 0.2100
# Epoch 7/100
# 1/1 [==============================] - 0s 25ms/step - loss: 2.2300 - accuracy: 0.2200
# Epoch 8/100
# 1/1 [==============================] - 0s 24ms/step - loss: 2.2083 - accuracy: 0.2100
# Epoch 9/100
# 1/1 [==============================] - 0s 23ms/step - loss: 2.1874 - accuracy: 0.2100
# Epoch 10/100
# 1/1 [==============================] - 0s 26ms/step - loss: 2.1685 - accuracy: 0.2100
# Epoch 11/100
# 1/1 [==============================] - 0s 26ms/step - loss: 2.1516 - accuracy: 0.2200
# Epoch 12/100
# 1/1 [==============================] - 0s 26ms/step - loss: 2.1342 - accuracy: 0.2200
# Epoch 13/100
# 1/1 [==============================] - 0s 25ms/step - loss: 2.1148 - accuracy: 0.2400
# Epoch 14/100
# 1/1 [==============================] - 0s 22ms/step - loss: 2.0957 - accuracy: 0.1900
# Epoch 15/100
# 1/1 [==============================] - 0s 24ms/step - loss: 2.0795 - accuracy: 0.1800
# Epoch 16/100
# 1/1 [==============================] - 0s 25ms/step - loss: 2.0654 - accuracy: 0.1900
# Epoch 17/100
# 1/1 [==============================] - 0s 29ms/step - loss: 2.0512 - accuracy: 0.2100
# Epoch 18/100
# 1/1 [==============================] - 0s 26ms/step - loss: 2.0367 - accuracy: 0.2100
# Epoch 19/100
# 1/1 [==============================] - 0s 24ms/step - loss: 2.0232 - accuracy: 0.2100
# Epoch 20/100
# 1/1 [==============================] - 0s 25ms/step - loss: 2.0114 - accuracy: 0.2100
# Epoch 21/100
# 1/1 [==============================] - 0s 28ms/step - loss: 2.0010 - accuracy: 0.2100
# Epoch 22/100
# 1/1 [==============================] - 0s 23ms/step - loss: 1.9904 - accuracy: 0.2300
# Epoch 23/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.9791 - accuracy: 0.2200
# Epoch 24/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9677 - accuracy: 0.2400
# Epoch 25/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9564 - accuracy: 0.2400
# Epoch 26/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9452 - accuracy: 0.2600
# Epoch 27/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9340 - accuracy: 0.2400
# Epoch 28/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.9228 - accuracy: 0.2500
# Epoch 29/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.9117 - accuracy: 0.2500
# Epoch 30/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.9005 - accuracy: 0.2500
# Epoch 31/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8893 - accuracy: 0.2600
# Epoch 32/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.8781 - accuracy: 0.2600
# Epoch 33/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.8668 - accuracy: 0.2900
# Epoch 34/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8552 - accuracy: 0.3000
# Epoch 35/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8435 - accuracy: 0.3000
# Epoch 36/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8315 - accuracy: 0.3000
# Epoch 37/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.8192 - accuracy: 0.2900
# Epoch 38/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.8059 - accuracy: 0.3000
# Epoch 39/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7916 - accuracy: 0.3100
# Epoch 40/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.7768 - accuracy: 0.3100
# Epoch 41/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.7627 - accuracy: 0.3300
# Epoch 42/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7540 - accuracy: 0.3300
# Epoch 43/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.7374 - accuracy: 0.3100
# Epoch 44/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7154 - accuracy: 0.3200
# Epoch 45/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.7111 - accuracy: 0.3500
# Epoch 46/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6840 - accuracy: 0.3300
# Epoch 47/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6744 - accuracy: 0.3500
# Epoch 48/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.6549 - accuracy: 0.3700
# Epoch 49/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6345 - accuracy: 0.3600
# Epoch 50/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.6246 - accuracy: 0.3700
# Epoch 51/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5982 - accuracy: 0.3800
# Epoch 52/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5850 - accuracy: 0.4000
# Epoch 53/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.5732 - accuracy: 0.4000
# Epoch 54/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.5428 - accuracy: 0.4300
# Epoch 55/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5276 - accuracy: 0.4200
# Epoch 56/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.5237 - accuracy: 0.4600
# Epoch 57/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.4912 - accuracy: 0.4600
# Epoch 58/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4675 - accuracy: 0.4500
# Epoch 59/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4621 - accuracy: 0.5200
# Epoch 60/100
# 1/1 [==============================] - 0s 23ms/step - loss: 1.4425 - accuracy: 0.4800
# Epoch 61/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4143 - accuracy: 0.5000
# Epoch 62/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.3938 - accuracy: 0.5500
# Epoch 63/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3862 - accuracy: 0.5200
# Epoch 64/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3823 - accuracy: 0.5400
# Epoch 65/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3486 - accuracy: 0.5400
# Epoch 66/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.3211 - accuracy: 0.5700
# Epoch 67/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3140 - accuracy: 0.6000
# Epoch 68/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3033 - accuracy: 0.5600
# Epoch 69/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.2771 - accuracy: 0.5800
# Epoch 70/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.2522 - accuracy: 0.5900
# Epoch 71/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.2441 - accuracy: 0.5600
# Epoch 72/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.2374 - accuracy: 0.5700
# Epoch 73/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.2125 - accuracy: 0.5600
# Epoch 74/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.1855 - accuracy: 0.6000
# Epoch 75/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.1729 - accuracy: 0.5900
# Epoch 76/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.1666 - accuracy: 0.5700
# Epoch 77/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.1506 - accuracy: 0.5800
# Epoch 78/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.1243 - accuracy: 0.6100
# Epoch 79/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.1061 - accuracy: 0.6000
# Epoch 80/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0985 - accuracy: 0.6100
# Epoch 81/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0885 - accuracy: 0.6000
# Epoch 82/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0688 - accuracy: 0.6200
# Epoch 83/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0455 - accuracy: 0.6400
# Epoch 84/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0312 - accuracy: 0.6400
# Epoch 85/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0235 - accuracy: 0.6600
# Epoch 86/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0119 - accuracy: 0.6400
# Epoch 87/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9927 - accuracy: 0.6800
# Epoch 88/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9720 - accuracy: 0.6800
# Epoch 89/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9592 - accuracy: 0.6800
# Epoch 90/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9512 - accuracy: 0.7000
# Epoch 91/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9397 - accuracy: 0.7200
# Epoch 92/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9231 - accuracy: 0.6900
# Epoch 93/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.9036 - accuracy: 0.7200
# Epoch 94/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8887 - accuracy: 0.7200
# Epoch 95/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8789 - accuracy: 0.7400
# Epoch 96/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8705 - accuracy: 0.7400
# Epoch 97/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8619 - accuracy: 0.6900
# Epoch 98/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8472 - accuracy: 0.7300
# Epoch 99/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8300 - accuracy: 0.7200
# Epoch 100/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8117 - accuracy: 0.7600
# Tensor("model/pointer_lstm/attention/Reshape:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_1:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_2:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_3:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_4:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_5:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_6:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_7:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_8:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_9:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_1:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_2:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_3:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_4:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_5:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_6:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_7:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_8:0", shape=(None, 10), dtype=float32)
# Tensor("model/pointer_lstm/attention/Reshape_9:0", shape=(None, 10), dtype=float32)
# 1/1 [==============================] - 3s 3s/step - loss: 3.0915 - accuracy: 0.2400
# evaluate :  [3.0914721488952637, 0.23999999463558197]
# ------

# %%
l[0]
# Out:
# array([[9.92462873e-01, 7.04305014e-03, 4.87826415e-04, 1.54287966e-06,
#         2.41436993e-07, 1.65162896e-06, 2.60639831e-06, 1.47462544e-07,
#         3.91749495e-08, 5.27143449e-08],
#        [4.21907417e-02, 8.37654248e-03, 9.30410549e-02, 6.41707564e-03,
#         2.98249885e-03, 4.16233748e-01, 4.28417474e-01, 1.77047786e-03,
#         1.50599721e-04, 4.19771270e-04],
#        [8.44437629e-03, 5.00161992e-03, 5.10086045e-02, 4.78134863e-03,
#         2.80828308e-03, 6.65301859e-01, 2.50135660e-01, 1.02581754e-02,
#         2.75498925e-04, 1.98456482e-03],
#        [6.60098204e-03, 6.25277534e-02, 2.57045895e-01, 3.44258040e-01,
#         8.32854658e-02, 2.84045264e-02, 8.11110437e-03, 1.16082989e-01,
#         2.22218707e-02, 7.14613944e-02],
#        [1.35947322e-03, 1.08926231e-02, 1.16293225e-02, 3.28363776e-01,
#         2.32959107e-01, 6.21747784e-03, 1.86699978e-03, 1.23788789e-01,
#         1.18597150e-01, 1.64325297e-01],
#        [9.62706748e-04, 7.18384981e-03, 5.04568731e-03, 3.10310960e-01,
#         2.52327472e-01, 4.54979297e-03, 1.54779060e-03, 1.07143775e-01,
#         1.43338293e-01, 1.67589679e-01],
#        [8.71292490e-04, 6.92544878e-03, 4.62813675e-03, 2.87354261e-01,
#         2.47318089e-01, 4.75086411e-03, 1.68783369e-03, 1.13204665e-01,
#         1.51559606e-01, 1.81699738e-01],
#        [8.44013004e-04, 6.80636615e-03, 4.65337886e-03, 2.51474380e-01,
#         2.35982224e-01, 5.92022482e-03, 2.11167848e-03, 1.36809513e-01,
#         1.55156642e-01, 2.00241625e-01],
#        [8.61107081e-04, 6.44609099e-03, 4.48578736e-03, 2.10684285e-01,
#         2.23939240e-01, 7.58043304e-03, 2.68345489e-03, 1.67818516e-01,
#         1.59120888e-01, 2.16380149e-01],
#        [8.57924228e-04, 5.92265418e-03, 4.06232756e-03, 1.90565422e-01,
#         2.23110646e-01, 8.11789464e-03, 2.86562787e-03, 1.78530455e-01,
#         1.63288772e-01, 2.22678289e-01]], dtype=float32)

# %%
x_test[0]
# Out:
# array([[2, 0],
#        [0, 6],
#        [8, 7],
#        [1, 4],
#        [1, 7],
#        [3, 1],
#        [7, 3],
#        [3, 4],
#        [1, 9],
#        [4, 7]])
